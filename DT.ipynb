# %%
import pandas as pd

# %%
data = pd.read_csv('/content/data_no_outliers.csv')
data.head()
# Out:
#    gender  race/ethnicity  parental level of education  lunch  \
# 0     1.0            0.25                          0.0    1.0
# 1     1.0            0.00                          0.2    1.0
# 2     1.0            1.00                          0.4    0.0
# 3     0.0            0.50                          0.4    0.0
# 4     0.0            0.75                          0.6    0.0
#
#    test preparation course  math score  reading score  writing score  \
# 0                      1.0    0.602410       0.525641         0.5625
# 1                      0.0    0.313253       0.282051         0.2250
# 2                      0.0    0.903614       0.743590         0.7875
# 3                      0.0    0.686747       0.615385         0.6375
# 4                      1.0    0.771084       0.858974         0.9000
#
#    Overall Score  Pass/Fail
# 0       0.527027          1
# 1       0.202703          0
# 2       0.797297          1
# 3       0.608108          1
# 4       0.824324          1

# %%
#Step 1: Import Needed Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

#Step 5: Apply Decision Tree
# Train the Decision Tree model
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

#Make predictions on the test set
y_pred = model.predict(X_test)

#Calculate the accuracy, precision, and recall of the classifier
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

#Confusion Matrix
confusion_mat = confusion_matrix(y_test, y_pred)

#Step 6: Evaluate the performance of DT model and visualize results
# 6.1.Print the metrics
print("\nAdditional Metrics for DT:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# 6.2.Plot the confusion matrix as a heatmap
sns.heatmap(confusion_mat, annot=True, cmap='YlGn', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for DT')
plt.savefig('naive_bayes.png', bbox_inches='tight')
plt.show()
# Out:
# Additional Metrics for DT:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0

# %%
print("\nConfusion Matrix for Decision Tree:")
print(confusion_mat)
print("\nClassification Report for Decision Tree:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix for Decision Tree:
# [[ 72   0]
#  [  0 201]]
#
# Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        72
#            1       1.00      1.00      1.00       201
#
#     accuracy                           1.00       273
#    macro avg       1.00      1.00      1.00       273
# weighted avg       1.00      1.00      1.00       273

# %%
Accuracy For Decision Tree : 100 %
Accuracy For SVC : 95.60439560439561 %
Accuracy For Naive Bayes : 73.992673992674 %

# %%
data.to_csv('exams.csv', index=False)
